# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,1,100)

# %%
def exp():
    for i in np.linspace(0,1,100):
        y = math.e**i

# %%
plt.plot(x,y)
plt.xlabel('time [milliseconds]')
plt.ylabel('awesomeness')
plt.savefig("expx.pdf")
